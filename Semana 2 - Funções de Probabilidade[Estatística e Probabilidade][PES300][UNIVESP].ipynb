# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🐲
# ---
# ###**Disciplina - Estatística e Probabilidade** 🌱
# ###Link: https://ava.univesp.br/ultra/courses/_3712_1/cl/outline
# ##Profª. Dra. Glauce Barbosa Verão 🌞
# ##Aluno: **Aelso Rocha Brito** 🤪
# ##**notebook**ComAnotaçõesDasVideoaulas 📵
# ---

# %% [markdown]
# #**2|Funções de Probabilidade** 🛸

# %% [markdown]
# **Antes de começar** ⏱
#
# Olá, alunos e alunas! 🎱
#
# Chegamos à segunda semana da disciplina de Estatística.
#
# Neste momento, apresentaremos os seguintes temas: **Teorema da Probabilidade Total e Teorema de Bayes; Funções probabilidade e densidade de probabilidade; parâmetros e suas propriedades**. 🅰
#
# Vamos começar?

# %% [markdown]
# **Orientação de estudo** 🔍
#
# Como orientação de estudo desta semana indicamos o seguinte roteiro:
# 1. Inicialmente, assista às videoaulas. Os slides apresentados encontram-se disponíveis para suas anotações;
# 2. Depois, estude o Material-base, que é o eixo central dos temas da semana;
# 3. Complemente seus estudos com o material de apoio - eles são de grande importância para fixar o conteúdo da semana e diversificar seu contato com outros materiais;
# 4. Realize o exercício de apoio para praticar seus conhecimentos.
#
# Bons estudos! 🤟

# %% [markdown]
# ##**Videoaula 5 - Teoremas de probabilidade** 🐇
#
# ####📑PDF:https://ava.univesp.br/bbcswebdav/xid-1852215_1;
#
# ####🎬Videoaula No YT:https://youtu.be/Q6PQkFYiCRs;
# ---

# %% [markdown]
# **Objetivos específicos da aula** 🌂
#
# * **Apresentar os principais teoremas do cálculo de probabilidades**

# %% [markdown]
# **Probabilidade Condicional**
#
# 2 eventos possíveis, A e B

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **B ocorreu - B é o novo espaço amostral**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Neste contexto,
#
# $P(A|B)=\frac{P(A∩B)}{P(B)}$

# %% [markdown]
# **Teorema do Produto** 🔻

# %% [markdown]
# **Considerando 2 eventos A e B**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $P(A|B)=\frac{P(A∩B)}{P(B)}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $P(B|A)=\frac{P(A∩B)}{P(A)}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $P(A∩B)=P(A).P(B/A)$
#
# $P(A∩B)=P(B).P(A/B)$

# %% [markdown]
# **Eventos Independentes**
#
# A informação sobre o evento B não altera A probabilidade de ocorrência de A.

# %% [markdown]
# $P(A/B)=P(A)$

# %% [markdown]
# **P(CHUVA/(DADO=6)) = P(CHUVA)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Evento Intersecção**
#
# $P(A∩B) = P(A).P(B)$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Teorema de Bayes**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Teorema de Bayes**
#
# $P(B)=Σ_{i=1}^nP(A_i∩B)=Σ_{i=1}^nP(A_i).P(B/A_i)$

# %% [markdown]
# **Resumo** 🌊
#
# * Probabilidade Condicional
# * Teorema do Produto
# * Teorema de Bayes

# %% [markdown]
# ##**Videoaula 6 - Exercícios sobre probabilidade** 🐘
#
# ####📑PDF:https://ava.univesp.br/bbcswebdav/xid-1852216_1;
#
# ####🎬Videoaula No YT:https://youtu.be/WEUzStGJIiQ;
# ---

# %% [markdown]
# **Objetivos específicos da aula**
# - Apresentar aplicações dos Teoremas De Probabilidade e Operações de eventos.

# %% [markdown]
# **Exercício Comentado**
#
# **Contexto**
#
# Numa determinada linha de produção sabe-se que 10% dos itens produzidos apresentam defeitos.
#
# Um teste para verificar a ocorrência de defeitos será aplicado nesta linha
# de produção.
#
# Este teste para detectar ou não a presença de defeitos garante 90% de acertos quando aplicado a itens efetivamente com defeitos e 80% de acertos quando aplicado a itens que não tem defeitos.

# %% [markdown]
# **Pergunta-se**
#
# Qual o percentual de itens realmente com defeitos dentre aqueles que o teste classificou como positivo (defeituoso)?

# %% [markdown]
# **Resolução Gráfica**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Dados Iniciais**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Resultados dos Testes**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Resultado Positivo (Defeito)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Realmente Defeituoso**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $P(POSITIVO)=0,18+0,09=0,27$
# $P(REALMENTE\  DEFEITUOSO \ ∩ POSITIVO)=0,18+0,09=0,27$
#
# $P(REALMENTE\ DEFEITUOSO\ /POSITIVO)=0,090,27=33\%$

# %% [markdown]
# **Pergunta-se**
# 2. Qual o percentual de itens não defeituosos dentre aqueles que o teste classificou como negativo(não defeituosos)?

# %% [markdown]
# **Resultado Negativo**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Realmente Negativo**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $P(NEGATIVO)=0,01+0,72=0,73$
# $P(NEGATIVO\ ∩ \ NÃO\ DEFEITO)=0,72$
# $P(NEGATIVO/NÃO\ DEFEITO)=0,720,73=98,6\%$

# %% [markdown]
# **Exercício Comentado**
#
# **Contexto:**
#
# **Funcionamento de um sistema de resistores**

# %% [markdown]
# |   |   |   |    | |
# |---|---|---|----|-|
# |   |0,7|   |0,85| |
# | A |0,7|0,9|    |B|
# |   |0,7|   |0,85| |

# %% [markdown]
# **Exercício Comentado**
#
# **Considerando a probabilidade de cada resistor estar funcionando, qual a chance do sistema funcionar (passar corrente entre A e B)?**

# %% [markdown]
# |   |   |   |    | |
# |---|---|---|----|-|
# |   |0,7|   |0,85| |
# | A |0,7|0,9|    |B|
# |   |0,7|   |0,85| |

# %% [markdown]
# **Exercício Comentado**
#
# Considerando a probabilidade de cada resistor estar funcionando, qual a chance do sistema funcionar (passar corrente entre A e B)?
# Resolução: $P(V\  OU\ W) = P(VUW) = 0,85 + 0,85 – 0,85.0,85 = 0,9775$

# %% [markdown]
# |   |   |   |    | |
# |---|---|---|----|-|
# |   |0,7|   |V 0,85| |
# | A |0,7|0,9|    |B|
# |   |0,7|   |W 0,85| |

# %% [markdown]
# $P(XYZ) = P(X\ OU\ Y\ OU\ Z) = P(XUYUZ) = 0,7 + 0,7 + 0,7 – 0,7.0,7 – 0,7.0,7 – 0,7.0,7 + 0,7.0,7.0,7 = 0,973$

# %% [markdown]
# |   |   |   |    | |
# |---|---|---|----|-|
# |   |X 0,7|   |0,85| |
# | A |Y 0,7|0,9|    |B|
# |   |Z 0,7|   |0,85| |

# %% [markdown]
# $P(sistema) = P(XYZ\ E\ K\ E\ VW) = P(XYZ∩K∩VW) = P(XYZ) . P(K) . P(VW) = 0,973.0,9. 0,9775 = 0,855977 ≈ 86\%$

# %% [markdown]
# |   |XYZ| K | VW | |
# |---|---|---|----|-|
# |   |0,7|   |0,85| |
# | A |0,7|0,9|    |B|
# |   |0,7|   |0,85| |

# %% [markdown]
# **EXERCÍCIO COMENTADO**

# %% [markdown]
# PROBLEMA DAS 3 PORTAS
#
# **(PROBLEMA DE MONTY HALL)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - O PARTICIPANTE ESCOLHE UMA PORTA;
# - O APRESENTADOR ABRE UMA DAS OUTRAS DUAS PORTAS;
# - O PARTICIPANTE DEVE TROCAR OU MANTER?

# %% [markdown]
# **RESOLUÇÃO GRÁFICA**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **PRIMEIRA ESCOLHA**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **PARTICIPANTE PERMANECE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **PARTICIPANTE TROCA**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Videoaula 7 - Variáveis aleatórias** 🎸
#
# ####📑PDF:https://ava.univesp.br/bbcswebdav/xid-1852217_1;
#
# ####🎬Videoaula No YT:https://youtu.be/K1MXYc_89D8;
# ---

# %% [markdown]
# **Objetivos específicos da aula**
# - Apresentar os conceitos de distribuições
# de probabilidade
# - Apresentar os principais parâmetros das
# distribuições de probabilidade

# %% [markdown]
# **Variável Aleatória**

# %% [markdown]
# |  |  |  |
# |--|--|--|
# |  |A |a |
# |A |AA|Aa|
# |a |aA|aa|

# %% [markdown]
# |EVENTO| PROBABILIDADE   |
# |------|-----------------|
# |{AA}|P(AA)=$\frac{1}{4}$|
# |{Aa}|P(aA)=$\frac{1}{2}$|
# |{aa}|P(aa)=$\frac{1}{4}$|

# %% [markdown]
# |  |  |  |
# |--|--|--|
# |  |A |a |
# |A |AA|Aa|
# |a |aA|aa|

# %% [markdown]
# Atribuir **descrição numérica** aos resultados dos **experimentos**

# %% [markdown]
# Descreve o valor que corresponde ao resultado de determinado experimento

# %% [markdown]
# |V.A   |PROBABILIDADE      |
# |------|-------------------|
# |X=0   |P(KK)=$\frac{1}{4}$|
# |X=1   |P(KC)=$\frac{1}{2}$|
# |X=2   |P(CC)=$\frac{1}{4}$|

# %% [markdown]
# Qual a função que associa os diferentes valores da V.A. aos resultados possíveis?
# - Central de relacionamento com clientes com 6 atendentes
# - Probabilidade de estar atendendo: $0,6$
# - Qual função descreve a probabilidade de estarem em atendimento?
# X = Número de atendentes ocupados
#
# $X = 0,1,2,3,4,5,6$

# %% [markdown]
# **Função Probabilidade**
#
# $P(X=0) = 0,4^6$
#
# $P(X=1)= 6x0,6x0,4^5$
#
# $P(X=2) = 15x0,6^2x0,4^4$
#
# $P(X=3) = 20x0,6^3x0,4^3$
#
# $P(X=4) = 15x0,6^4x0,4^2$
#
# $(PX=5)=6x0,6^5x0,4$
#
# $P(X=6)=0,66$

# %% [markdown]
# $P(X=0) = 0,0041$
#
# $P(X=1) = 0,0369$
#
# $P(X=2) = 0,1382$
#
# $P(X=3) = 0,2765$
#
# $P(X=4) = 0,3110$
#
# $P(X=5) = 0,1866$
#
# $P(X=6) = 0,0467$

# %% [markdown]
# Função Probabilidade - Formato tabela
#
# |x| P(X)|
# |-|------|
# |0|0,0041|
# |1|0,0369|
# |2|0,1382|
# |3|0,2765|
# |4|0,3110|
# |5|0,1866|
# |6|0,0467|

# %% [markdown]
# **Função Probabilidade - Formato gráfico**
#
# X = Número de atendentes ocupados

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Função Probabilidade - Formato expressão**
#
# $P(X=k)= \left(\begin{array}{cc}6 \\8 \end{array}\right).0,6^k.0,4^{6-k}$

# %% [markdown]
# **Variáveis Aleatórias**
#
# **Variáveis Aleatórias Discretas** – Admite um número finito de valores ou tem uma quantidade enumerável de valores.
#
# **Variáveis Aleatórias Contínuas** – Pode tomar um número infinito de valores podem ser associadas a mensurações em uma escala continua.

# %% [markdown]
# **Variáveis Aleatórias Discretas**
#
# Admite um número finito de valores ou tem uma quantidade enumerável de valores.

# %% [markdown]
# **Função Probabilidade – Discreta**
#
# Propriedades
#
# a. $P(X=x_0) ≥ 0$
#
# b. $ΣP(X=x_0)=1$

# %% [markdown]
# **Variáveis Aleatórias**
#
# **Variáveis Aleatórias Continuas**
#
# Pode tomar um número infinito de valores e esses valores podem ser associados a mensurações em uma escala contínua.

# %% [markdown]
# $P(X = 0,2000000...m) = 0$

# %% [markdown]
# **Propriedades**
#
# a) $f(x) ≥ 0$
#
# b)$ _a^b\int f(x)dx=P(a<x≤b) , b ≥ a$
#
# c)$\int _{-∞} ^{+∞}f(x)dx=1$

# %% [markdown]
# **Propriedades das Distribuições de Probabilidade**
# - Esperança matemática (média)
# - Variância
# - Desvio padrão

# %% [markdown]
# Esperança matemática (média)
#
# $μ= E_{(x)}= Σxi.p(x_i)$
#
# |Xi|P(Xi)        |
# |--|-------------|
# |1 |$\frac{1}{6}$|
# |2 |$\frac{1}{6}$|
# |3 |$\frac{1}{6}$|
# |4 |$\frac{1}{6}$|
# |5 |$\frac{1}{6}$|
# |6 |$\frac{1}{6}$|
#
# - Exemplo: lançamento dado
#
# $μ= \frac{1}{6}.1+\frac{1}{6}.2+\frac{1}{6}.3+\frac{1}{6}.4+\frac{1}{6}.5+\frac{1}{6}.6= \frac{21}{6}=\frac{7}{2}$

# %% [markdown]
# Esperança matemática (média)
#
# $μ= E_{(x)}= Σxi.p(x_i)$
#
# $μ= E_{(x)}=\int _{-∞} ^{+∞}xf(x)dx$

# %% [markdown]
# **Variância e Desvio Padrão**
#
# *Variância - VAR (X)*
#
# Grau de dispersão de probabilidade em torno da média.
#
# *Variância - VAR (x)*
#
# $\alpha^2 =Σ(x_i- μ)^2.p(x_i)=E[X- μ)^2]$
#
# $\alpha^2=[Σx^2.p(x)]- \mu^2 =E(X^2)-[E(X)]^2$

# %% [markdown]
# **Variância - VAR (X)**
#
# Lançamento de dado
#
# |Xi|P(Xi)        |
# |--|-------------|
# |1 |$\frac{1}{6}$|
# |2 |$\frac{1}{6}$|
# |3 |$\frac{1}{6}$|
# |4 |$\frac{1}{6}$|
# |5 |$\frac{1}{6}$|
# |6 |$\frac{1}{6}$|

# %% [markdown]
# $\alpha^2=(1-\frac{7}{2})^2.\frac{1}{6}+(2-\frac{7}{2})^2.\frac{1}{6}+(3-\frac{7}{2})^2.\frac{1}{6}+(4-\frac{7}{2})^2.\frac{1}{6}+(5-\frac{7}{2})^2.\frac{1}{6}+(6-\frac{7}{2})^2.\frac{1}{6}$
#
# $\alpha^2=\frac{35}{12}=2,9$

# %% [markdown]
# **Propriedades da Média**
# - E(k)=k, se k é constante
# - E(X.k) = k . E(X)
# - E(X+Y)=E(X)+E(Y)
# - E(X-Y)=E(X)-E(Y)
# - E(X.Y) = E(X).E(Y) se X e Y independentes

# %% [markdown]
# **Propriedades da Variância**
#
# $\sigma^2 (k) = 0$ se $k$ é constante
#
# $\sigma^2(X.k) = k^2.\sigma^2(X)$
#
# $\sigma^2(X+Y) = \sigma^2(X) + \sigma^2(Y)$ se X e Y independentes
#
# $\sigma^2(X-Y) = \sigma^2(X) + \sigma^2(Y)$ se X e Y independentes

# %% [markdown]
# **Variância e Desvio Padrão**
#
# **Variância - VAR (x)**
#
# Desvio padrão = $\sqrt{variância}$

# %% [markdown]
# **Mediana**
# - Valor numérico que separa o conjunto pela metade
# - Conjunto $\{3 , 3 , 5 , 7 , 9\}$
# - Md = $5$

# %% [markdown]
# **Moda**
# - Valor numérico de maior frequência
# - Conjunto $\{ 3 , 3 , 5 , 7 , 9\}$
# - Mo = $3$

# %% [markdown]
# **Resumo**
#
# - **Variáveis Aleatórias**
# - **Função Probabilidade**
# - **Esperança**
# - **Variância**
# - **Desvio padrão, mediana, moda**

# %% [markdown]
# ##**Videoaula 08 - Exercícios sobre variáveis aleatórias** 🌵
#
# ####📑PDF:https://ava.univesp.br/bbcswebdav/xid-1852218_1;
#
# ####🎬Videoaula No YT:https://youtu.be/rsbhyTtwHfg;
# ---

# %% [markdown]
# **Objetivos específicos da aula** 🌍
#
# **Apresentar aplicações dos conceitos de Variáveis aleatórias**

# %% [markdown]
# **Exercício comentado** 🧯

# %% [markdown]
# **Distribuições Discretas**
#
# **Contexto**
#
# 4 bolas brancas
#
# 2 bolas pretas

# %% [markdown]
# Distribuição de probabilidade
#
# “V.A.(X) : obter 2 bolas pretas”

# %% [markdown]
# **Espaço amostral**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $C_{6,2}= \frac{6!}{2!6-2!}= \frac{6x5x4!}{2!x4!}= \frac{30}{2}=15$

# %% [markdown]
# $p(x=2)=\frac{2}{6}.\frac{1}{5}=\frac{1}{5}$
#
# $p(x=3)=\frac{2}{6}.\frac{4}{5}.\frac{1}{4}.2=\frac{2}{5}$
#
# $p(x=4)=\frac{2}{6}.\frac{4}{5}.\frac{3}{4}. \frac{1}{3}.3=\frac{3}{5}$
#
# $p(x=5)=\frac{2}{6}.\frac{4}{5}.\frac{3}{4}. \frac{2}{3}.\frac{1}{2}.4= \frac{4}{5}$
#
# $p(x=6)=\frac{2}{6}.\frac{4}{5}.\frac{3}{4}. \frac{2}{3}.\frac{1}{2}.\frac{1}{1}.5= \frac{5}{15}$

# %% [markdown]
# $p(x=0)=0$
#
# $p(x=1)=0$
#
# $p(x=2)=\frac{1}{15}$
#
# $p(x=3)=\frac{2}{15}$
#
# $p(x=4)=\frac{3}{15}=\frac{1}{5}$
#
# $p(x=5)=\frac{4}{15}$
#
# $p(x=6)=\frac{5}{15}=\frac{1}{3}$

# %% [markdown]
# $f(X)=\begin{cases}\frac{X-1}{15}
# \ para\ X=2,3,4,5,6 \\
# 0\ do\ contrário\end{cases}$

# %% [markdown]
# **Exercício comentado**

# %% [markdown]
# **Contexto**

# %% [markdown]
# **Confecção**
#
# Vestido Camiseta Terno Camisa

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Inverno Frio = $0,4$
#
# Inverno Quente = $0,6$

# %% [markdown]
# **Resultados esperados**
#
# |              |Vestido|Camiseta|Terno|Camisa|
# |--------------|-------|--------|-----|------|
# |Inverno Quente|800    |100     |-100 |-300  |
# |Inverno Frio  |-300   |-50     |150  |500   |

# %% [markdown]
# **Projeção**
#
# |              |P (probabilidade)|Vestido|Camiseta|Terno|Camisa|
# |--------------|-----------------|-------|--------|-----|------|
# |Inverno Quente|0,6              |800    |100     |-100 |-300  |
# |Inverno Frio  |0,4              |-300   |-50     |150  |500   |

# %% [markdown]
# |              |P (probabilidade)|Vestido|Camiseta|Terno|Camisa|
# |--------------|-----------------|-------|--------|-----|------|
# |Inverno Quente|**0,6**          |**800**   |100     |-100 |-300  |
# |Inverno Frio  |**0,4**          |**-300**  |-50     |150  |500   |
#
# $E(V) = 0,6x800 + 0,4x(-300) = 360$

# %% [markdown]
# |              |P (probabilidade)|Vestido|Camiseta|Terno|Camisa|
# |--------------|-----------------|-------|--------|-----|------|
# |Inverno Quente|**0,6**          |800   |**100**  |-100 |-300  |
# |Inverno Frio  |**0,4**          |-300  |**-50** |150  |500   |
#
# $E(C) = 0,6x100 + 0,4x(-50) = 40$

# %% [markdown]
# |              |P (probabilidade)|Vestido|Camiseta|Terno|Camisa|
# |--------------|-----------------|-------|--------|-----|------|
# |Inverno Quente|**0,6**          |800   |100 |**-100** |-300  |
# |Inverno Frio  |**0,4**          |-300  |-50 |**150**  |500   |
#
# $E(K)=0,6x(-100)+0,4x(150)=0$

# %% [markdown]
# |              |P (probabilidade)|Vestido|Camiseta|Terno|Camisa|
# |--------------|-----------------|-------|--------|-----|------|
# |Inverno Quente|**0,6**          |800   |100 |-100 |-300  |
# |Inverno Frio  |**0,4**          |-300  |-50 |150 |500   |
#
# $E(T) = 0,6x(-300) + 0,4x(500) = 20$

# %% [markdown]
# **Resultados esperados**
#
# $E(V) = 360$
#
# $E(C) = 40$
#
# $E(K) = 0$
#
# $E(T) = 20$
#
# Melhor Opção: Vestidos

# %% [markdown]
# **Valores muito elevados**
#
# |              |P (probabilidade)|Vestido|Camiseta|Terno|Camisa|
# |--------------|-----------------|-------|--------|-----|------|
# |Inverno Quente|0,6              |800    |100     |-100 |-300  |
# |Inverno Frio  |0,4              |-300   |-50     |150  |500   |

# %% [markdown]
# |              |P (probabilidade)|Vestido|Camiseta|Terno|Camisa|
# |--------------|-----------------|-------|--------|-----|------|
# |Inverno Quente|**0,6**          |800   |100 |**-100** |-300  |
# |Inverno Frio  |**0,4**          |-300  |-50 |**150**  |500   |
#
# $E(K)=0,6x(-100)+0,4x(150)=0$

# %% [markdown]
# **Valores reduzidos**
#
# |              |P (probabilidade)|Vestido|Camiseta|Terno|Camisa|
# |--------------|-----------------|-------|--------|-----|------|
# |Inverno Quente|0,6              |800    |100     |-100 |-300  |
# |Inverno Frio  |0,4              |-300   |-50     |150  |500   |

# %% [markdown]
# **Projeção**

# %% [markdown]
# |              |P (probabilidade)|Vestido|Camiseta|Terno|Camisa|
# |--------------|-----------------|-------|--------|-----|------|
# |Inverno Quente|**0,6**          |**800**   |100     |-100 |-300  |
# |Inverno Frio  |**0,4**          |**-300**  |-50     |150  |500   |
#
# $E(V) = 0,6x800 + 0,4x(-300) = 360$

# %% [markdown]
# **Conclusões** 🍅
#
# - Se os valores são “razoáveis” os prejuízos são assimiláveis e o critério de decisão deve ser o melhor valor esperado.
# - Porém se os valores são muito elevados e os prejuízos são significativos então somos avessos ao risco.
# - Por outro lado, se os valores são muito pequenos,então somos propensos ao risco.

# %% [markdown]
# [Material de Apoio - confira os vídeos e os mini aplicativos indicados na página do Ativestat, a seguir](https://www.ime.usp.br/ativestat/probabilidade-modelos.php) 💀

# %% [markdown]
# [Texto-base - Material-base das aulas 5 a 8 | André Leme Fleury](https://ava.univesp.br/bbcswebdav/pid-513259-dt-content-rid-2057991_1/xid-2057991_1) 💊

# %% [markdown]
# [Material de apoio - Applet 1 - The Canonical Roulette | David P. Little - Penn State University](http://www.math.psu.edu/dlittle/java/probability/canonicalroulette/index.html) ⬜

# %% [markdown]
# [Material de apoio - Applet 2 - Random Babies | Rossman](http://www.rossmanchance.com/applets/randomBabies/RandomBabies.html) ⬜

# %% [markdown]
# [Material de apoio - Applet 3 - Birthday Experiment | Math Uah](http://www.randomservices.org/random/apps/BirthdayExperiment.html) ⬜

# %% [markdown]
# [Material de apoio - Applet 4 - Die Coin Experiment | Math Uah](http://www.randomservices.org/random/apps/DieCoinExperiment.html)⬜

# %% [markdown]
# [Material de apoio - Applet 5 - Dice Experiment | Math Uah](http://www.randomservices.org/random/apps/DiceExperiment.html)⬜

# %% [markdown]
# [Vídeo de Apoio - Variáveis aleatórias | Khanacademy](https://www.khanacademy.org/math/probability/random-variables-topic/random_variables_prob_dist/v/random-variables) 🎬

# %% [markdown]
# [Vídeo de Apoio - Probability density function | Khanacademy](https://www.khanacademy.org/math/probability/random-variables-topic/random_variables_prob_dist/v/probability-density-functions)🎬

# %% [markdown]
# [Vídeo de Apoio - Time life insurance and death probability | Khanacademy](https://www.khanacademy.org/math/probability/v/term-life-insurance-and-death-probability) 🎬

# %% [markdown]
# [Exercício de apoio - Semana 2](https://ava.univesp.br/bbcswebdav/pid-513268-dt-content-rid-2057992_1/xid-2057992_1) 🏇

# %% [markdown]
# **Em síntese - Semana 2** 🔥
#
# Na próxima semana de curso, estudaremos sobre "Distribuições de Probabilidade" e "Amostragem - Conceitos fundamentais".
#
# Até lá! 😩
